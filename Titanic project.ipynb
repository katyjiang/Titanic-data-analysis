# %% [markdown]
# In this project, I am going to diving into the data of Titanic disaster, using all those data to analyse several questions.
# 1. who were the people on the ship?
# 2. what deck were the passengers on and how does that relate to their class?
# 3. where is passengers come from?
# 4. who was alone and who was with family?
# 5. what factor help peopel survive ?
# 6. Did the deck have an effect on the survival rate?
# 7. Did having a family member increase the odds of surviving the crash?

# %% [markdown]
# 1. who were the people on the ship?

# %%
# we import pandas to look up the data.
import pandas as pd
from pandas import Series, DataFrame

# %%
titanic_df = pd.read_csv('train.csv')

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
#who were the people on the ship
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.factorplot('Sex',data=titanic_df,kind='count')
# This was part of the updates to categorical plots 
#for 0.6 (by the way this is not well-advertised but 
#the development version is documented here). 
#Because the plots can be drawn horizontally or vertically, 
#you now have to specify kind="count" in factorplot (or use 
#the axes-level countplot function) rather than not passing 
#a quantitative variable.

# %%
sns.factorplot('Sex',data=titanic_df,hue='Pclass',kind='count')

# %%
sns.factorplot('Pclass',data=titanic_df,hue='Sex',kind='count')

# %%
def male_female_child(passenger):
    age,sex = passenger
    
    if age < 16:
        return'child'
    else:
        return sex

# %%
titanic_df['person']= titanic_df[['Age','Sex']].apply(male_female_child,axis=1)

# %%
titanic_df[0:10]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
 sns.factorplot('person',data=titanic_df,kind='count')

# %%
sns.factorplot('Pclass',data=titanic_df,hue='person',kind='count')

# %%
titanic_df['Age'].hist(bins=70)

# %%
titanic_df['Age'].mean()
# Out:
# 29.69911764705882

# %%
titanic_df['person'].value_counts()
# Out:
# male      537
# female    271
# child      83
# Name: person, dtype: int64

# %%
fig = sns.FacetGrid(titanic_df,hue='Sex',aspect=4)
fig.map(sns.kdeplot,'Age',shade=True)

oldest = titanic_df['Age'].max()

fig.set(xlim=(0,oldest))

fig.add_legend()

# %%
fig = sns.FacetGrid(titanic_df,hue='person',aspect=4)
fig.map(sns.kdeplot,'Age',shade=True)

oldest = titanic_df['Age'].max()

fig.set(xlim=(0,oldest))

fig.add_legend()

# %%
fig = sns.FacetGrid(titanic_df,hue='Pclass',aspect=4)
fig.map(sns.kdeplot,'Age',shade=True)

oldest = titanic_df['Age'].max()

fig.set(xlim=(0,oldest))

fig.add_legend()

# %%
#what deck were the passengers on and how does
#that relate to their class?

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  person
# 0      0         A/5 21171   7.2500   NaN        S    male
# 1      0          PC 17599  71.2833   C85        C  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female
# 3      0            113803  53.1000  C123        S  female
# ...

# %%
deck = titanic_df['Cabin'].dropna()

# %%
deck.head()
# Out:
# 1      C85
# 3     C123
# 6      E46
# 10      G6
# 11    C103
# Name: Cabin, dtype: object

# %%
levels = []

for level in deck:
     levels.append(level[0])
        

from collections import Counter
Counter(levels)
# Out:
# Counter({'A': 15, 'B': 47, 'C': 59, 'D': 33, 'E': 32, 'F': 13, 'G': 4, 'T': 1})

# %%
cabin_df = DataFrame(levels)
cabin_df.columns = ['Cabin']
sns.factorplot('Cabin', data=cabin_df,kind='count',order=['A','B','C','D','E','F','G','T'],palette='winter_d')

# %%
cabin_df = cabin_df[cabin_df.Cabin !='T']
sns.factorplot('Cabin', data=cabin_df,kind='count',order=['A','B','C','D','E','F','G'],palette='winter_d')

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  person
# 0      0         A/5 21171   7.2500   NaN        S    male
# 1      0          PC 17599  71.2833   C85        C  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female
# 3      0            113803  53.1000  C123        S  female
# ...

# %%
# where is passengers come from?
sns.factorplot('Embarked',data=titanic_df,hue='Pclass',kind='count',
               size=5,order=['C','Q','S'])

# %%
#who was alone and who was with family?
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  person
# 0      0         A/5 21171   7.2500   NaN        S    male
# 1      0          PC 17599  71.2833   C85        C  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female
# 3      0            113803  53.1000  C123        S  female
# ...

# %%
titanic_df['Alone'] = titanic_df.SibSp + titanic_df.Parch

# %%
titanic_df['Alone']
# Out:
# 0       1
# 1       1
# 2       0
# 3       1
# 4       0
# 5       0
# 6       0
# 7       4
# 8       2
# 9       1
# 10      2
# 11      0
# 12      0
# 13      6
# 14      0
# 15      0
# 16      5
# 17      0
# 18      1
# 19      0
# 20      0
# 21      0
# 22      0
# 23      0
# 24      4
# 25      6
# 26      0
# 27      5
# 28      0
# 29      0
#        ..
# 861     1
# 862     0
# 863    10
# 864     0
# 865     0
# 866     1
# 867     0
# 868     0
# 869     2
# 870     0
# 871     2
# 872     0
# 873     0
# 874     1
# 875     0
# 876     0
# 877     0
# 878     0
# 879     1
# 880     1
# 881     0
# 882     0
# 883     0
# 884     0
# 885     5
# 886     0
# 887     0
# 888     3
# 889     0
# 890     0
# Name: Alone, Length: 891, dtype: int64

# %%
titanic_df['Alone'].loc[titanic_df['Alone']>0] = 'With Family'
titanic_df['Alone'].loc[titanic_df['Alone']==0] = 'Alone'
# Out:
# /Users/katy/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
titanic_df['Alone']
# Out:
# 0      With Family
# 1      With Family
# 2            Alone
# 3      With Family
# 4            Alone
# 5            Alone
# 6            Alone
# 7      With Family
# 8      With Family
# 9      With Family
# 10     With Family
# 11           Alone
# 12           Alone
# 13     With Family
# 14           Alone
# 15           Alone
# 16     With Family
# 17           Alone
# 18     With Family
# 19           Alone
# 20           Alone
# 21           Alone
# 22           Alone
# 23           Alone
# 24     With Family
# 25     With Family
# 26           Alone
# 27     With Family
# 28           Alone
# 29           Alone
#           ...
# 861    With Family
# 862          Alone
# 863    With Family
# 864          Alone
# 865          Alone
# 866    With Family
# 867          Alone
# 868          Alone
# 869    With Family
# 870          Alone
# 871    With Family
# 872          Alone
# 873          Alone
# 874    With Family
# 875          Alone
# 876          Alone
# ...

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  person        Alone
# 0      0         A/5 21171   7.2500   NaN        S    male  With Family
# 1      0          PC 17599  71.2833   C85        C  female  With Family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female        Alone
# ...

# %%
sns.factorplot('Alone',data = titanic_df,kind='count',palette='Blues')

# %%
#what factor help peopel survive ?
#mapping lecture36
titanic_df['Survivor'] = titanic_df.Survived.map({0:'no',1:'yes'})
sns.factorplot('Survivor',data=titanic_df,palette='Blues',kind='count',hue='Sex')

# %%
sns.factorplot('Pclass','Survived',hue='person',data=titanic_df)

# %%
sns.lmplot('Age','Survived',data = titanic_df)

# %%
sns.lmplot('Age','Survived',hue='Pclass',data = titanic_df)

# %%
generation = [10,20,40,60,80]

sns.lmplot('Age','Survived',hue='Pclass',data=titanic_df,x_bins=generation)

# %%
sns.lmplot('Age','Survived',hue='Sex',data = titanic_df,x_bins=generation)

# %%
#Did the deck have an effect on the survival rate?

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  person        Alone  \
# 0      0         A/5 21171   7.2500   NaN        S    male  With Family
# 1      0          PC 17599  71.2833   C85        C  female  With Family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female        Alone
# ...

# %%
deck = titanic_df['Cabin'].dropna()

# %%
len(deck)
# Out:
# 204

# %%
len(titanic_df)
# Out:
# 891

# %%
titanicDF = titanic_df.dropna(subset=['Cabin'])

# %%
len(titanicDF)
# Out:
# 204

# %%
titanicDF
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# 21            22         1       2
# 23            24         1       1
# 27            28         0       1
# 31            32         1       1
# 52            53         1       1
# 54            55         0       1
# 55            56         1       1
# 61            62         1       1
# 62            63         0       1
# 66            67         1       2
# 75            76         0       3
# 88            89         1       1
# 92            93         0       1
# 96            97         0       1
# 97            98         1       1
# 102          103         0       1
# 110          111         0       1
# 118          119         0       1
# 123          124         1       2
# 124          125         0       1
# ...

# %%
len(levels)
# Out:
# 204

# %%
titanicDF['Deck']=levels
# Out:
# /Users/katy/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
titanicDF
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# 21            22         1       2
# 23            24         1       1
# 27            28         0       1
# 31            32         1       1
# 52            53         1       1
# 54            55         0       1
# 55            56         1       1
# 61            62         1       1
# 62            63         0       1
# 66            67         1       2
# 75            76         0       3
# 88            89         1       1
# 92            93         0       1
# 96            97         0       1
# 97            98         1       1
# 102          103         0       1
# 110          111         0       1
# 118          119         0       1
# 123          124         1       2
# 124          125         0       1
# ...

# %%
sns.factorplot('Deck','Survived',data=titanicDF,order=['A','B','C','D','E','F','G'])

# %%
#Did having a family member increase the odds of surviving the crash?

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
sns.factorplot('Alone','Survived',data=titanic_df)
#peopel with fam seems have highly survival rate

# %%
sns.factorplot('Alone','Survived',data=titanic_df,hue='person')
# woman and children have higher survival rate when they are alone

# %%
sns.factorplot('Alone','Survived',data=titanic_df,hue='Pclass',col='person',col_order=['male','female','child'])

# %%
sns.factorplot('Alone','Survived',data=titanic_df,hue='person',col='Pclass',col_order=[1,2,3])
